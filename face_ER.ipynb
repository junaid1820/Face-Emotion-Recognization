# %%
import cv2

# %%
from deepface import DeepFace

# %%
img = cv2.imread("happy.jpg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
pred = DeepFace.analyze(img)
# Out:
# Action: race: 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.77it/s]

# %%
pred
# Out:
# [{'emotion': {'angry': 2.325979053807714e-06,
#    'disgust': 5.7590227031667496e-08,
#    'fear': 2.1323113230664603e-05,
#    'happy': 99.83327984809875,
#    'sad': 0.0007212942364276387,
#    'surprise': 1.0045676646086577e-05,
#    'neutral': 0.1659691333770752},
#   'dominant_emotion': 'happy',
#   'region': {'x': 780, 'y': 522, 'w': 1602, 'h': 1602},
#   'age': 16,
#   'gender': {'Woman': 1.2090557254850864, 'Man': 98.79094958305359},
#   'dominant_gender': 'Man',
#   'race': {'asian': 0.006789405515609396,
#    'indian': 0.0008739625495290791,
#    'black': 2.9276210318774758e-05,
#    'white': 98.85558499627292,
#    'middle eastern': 0.5665483674796382,
#    'latino hispanic': 0.5701666483829441},
#   'dominant_race': 'white'}]

# %%
type(pred)
# Out:
# list

# %%
type(pred[0])
# Out:
# dict

# %%
pred[0]['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#It contains the pre-trained parameters and features necessary to detect frontal faces using Haar-like features and a cascade classifier.

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),35)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font= cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,
           pred[0]["dominant_emotion"],
           (0,500),
           font, 20,
           (0,0,255),
           25,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sadwomen.jpeg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|███████████████████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.93it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 2.2704756906061543,
#    'disgust': 1.2732584374238922,
#    'fear': 10.633953138118608,
#    'happy': 0.059245001679882205,
#    'sad': 85.04433214135979,
#    'surprise': 0.026881074588021685,
#    'neutral': 0.6918516582278421},
#   'dominant_emotion': 'sad',
#   'region': {'x': 101, 'y': 34, 'w': 126, 'h': 126},
#   'age': 26,
#   'gender': {'Woman': 0.1249493332579732, 'Man': 99.87504482269287},
#   'dominant_gender': 'Man',
#   'race': {'asian': 87.399822473526,
#    'indian': 0.5611286498606205,
#    'black': 0.3267113585025072,
#    'white': 2.1912170574069023,
#    'middle eastern': 0.18026256002485752,
#    'latino hispanic': 9.340857714414597},
#   'dominant_race': 'asian'}]

# %%
import cv2 ### pip install opencv-python ## pip install opencv-contrib-python fullpackage from deepface import DeepFace ## pip install deepface

from deepface import DeepFace

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap= cv2.VideoCapture(0)

# Check if the webcam is opened correctly

if not cap.isOpened():
    cap= cv2.VideoCapture(0)

if not cap.isOpened():

    raise IOError("Cannot open webcam")

while True:

    ret,frame  = cap.read()

    result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) #print (faceCascade.empty()) faces faceCascade.detectMultiScale(gray,1.1,4)
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    #Draw a rectangle around the faces

    for(x, y, w, h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
    font = cv2.FONT_HERSHEY_SIMPLEX
                                        
    cv2.putText(frame,
            result[0]["dominant_emotion"].upper(),
            (100,100),
            font, 3,
            (0,0,255),
            2,
            cv2.LINE_4)
    cv2.imshow('Original video',frame)
    if cv2.waitKey(2) & 0XFF ==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 19.43it/s]
